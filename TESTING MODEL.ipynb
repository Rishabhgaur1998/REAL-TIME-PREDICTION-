# %%
import mediapipe as mp
import  cv2
import numpy as np
import sys
import csv
import os
import pandas as pd
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle 
from tensorflow.keras.utils import to_categorical
from matplotlib import pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from keras import models
mp_holistic = mp.solutions.holistic
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
import re
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import mediapipe as mp
#       2 import  cv2
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'mediapipe'

# %%
# !pip install mediapipe
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/51.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/51.0 MB 3.2 MB/s eta 0:00:16
#    ---------------------------------------- 0.2/51.0 MB 2.9 MB/s eta 0:00:18
#    ---------------------------------------- 0.4/51.0 MB 3.0 MB/s eta 0:00:17
#    ---------------------------------------- 0.5/51.0 MB 3.0 MB/s eta 0:00:17
#     --------------------------------------- 0.7/51.0 MB 3.0 MB/s eta 0:00:17
#     --------------------------------------- 0.8/51.0 MB 3.1 MB/s eta 0:00:17
#     --------------------------------------- 0.9/51.0 MB 2.8 MB/s eta 0:00:18
#     --------------------------------------- 1.0/51.0 MB 2.7 MB/s eta 0:00:19
#     --------------------------------------- 1.2/51.0 MB 2.9 MB/s eta 0:00:18
#    - -------------------------------------- 1.4/51.0 MB 3.0 MB/s eta 0:00:17
# ...

# %%
def mp_d(image,model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = holistic.process(image)
    
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results
def extract_pts(results):
    posr = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)   
    return posr

def draw_landmarks(image,results):
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
#     mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                              mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
#                              mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
#                              ) 
#     # Draw right hand connections  
#     mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                              mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
#                              mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
#                              )

# %%
lengthop=150
actions = ['lunges','Standing']
a_dict = {'lunges': ['C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/1.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/2.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/3.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/4.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/5.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/6.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/7.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/8.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/9.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/10.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/11.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/12.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/13.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/14.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/15.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/16.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/17.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/18.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/19.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/20.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/21.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/22.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/23.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/24.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/25.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/27.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/28.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/29.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/30.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/31.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/32.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/33.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/34.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/35.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/36.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/37.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/38.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/39.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/40.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/41.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/42.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/43.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/44.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/45.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/46.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/47.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/48.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/49.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/50.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/51.mp4'],
          'Standing': ['C:/Users/psibo/Pictures/Camera Roll/Combines/standing0.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing1.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing2.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing3.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing4.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing5.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing6.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing7.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing8.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing9.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing10.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing11.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing12.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing13.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing14.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing15.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing16.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing17.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing18.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing19.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing20.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing21.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing22.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing23.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing24.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing25.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing26.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing27.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing28.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing29.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing30.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing31.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing32.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing33.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing34.mp4',
                     'C:/Users/psibo/Pictures/Camera Roll/Combines/standing35.mp4']
        }



label_map = {label:num for num, label in enumerate(a_dict)}

# %%
label_map
# Out:
# {'lunges': 0, 'Standing': 1}

# %%
DATA_PATH = os.path.join('MP_Data')

# %%
sequences, labels = [], []
for action,videos in a_dict.items():
    for vid in videos:
        cap = cv2.VideoCapture(vid)
        filename = re.search('Camera Roll/Combines/(.+?).mp4',vid).group(1)  
        length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        print(vid)
        window = []
        for frame_num in range(lengthop):
            print(frame_num)
            print(vid)
            res = np.load(os.path.join(DATA_PATH, action, filename, "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
# Out:
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 0
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 1
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 2
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 3
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 4
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 5
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 6
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 7
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 8
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 9
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 10
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 11
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 12
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 13
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 14
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 15
# C:/Users/psibo/Pictures/Camera Roll/Combines/0.mp4
# 16
# ...

# %%
np.array(sequences).shape
# Out:
# (87, 150, 132)

# %%
np.array(sequences).shape
xx=np.array(sequences)
yy = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(xx, yy, test_size=0.4,random_state=12)

# %%
# model2 = tensorflow.keras.models.load_model('bestmodel.h5')
model2.summary()
yhat = model2.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()
multilabel_confusion_matrix(ytrue, yhat)
accuracy_score(ytrue, yhat)

# %%
# model2 = tensorflow.keras.models.load_model('bestmodel.h5')
model2.summary()
yhat = model2.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()
multilabel_confusion_matrix(ytrue, yhat)
accuracy_score(ytrue, yhat)

# %% [markdown]
# # UPLOADING SAVED MODEL

# %%
model3 = tensorflow.keras.models.load_model('lungesonly.h5')

# %%
width = 1000
height =800
dim = (width, height)

colors = [(245,117,16), (117,245,16), (16,117,245)]
# def prob_viz(res, actions, input_frame, colors):
# #     print(actions)
#     output_frame = input_frame.copy()
#     for num, prob in enumerate(res):
#         cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#         cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
#     return output_frame

# %%
sequence = []
seq = []
fc =0
sentence = []
threshold = 0.5
counter = 0
r = input("enter the 0 if you want to predict lunges")
r = str(r)
if r =="0":
    k = 'lunges'
    cap = cv2.VideoCapture('C:/Users/psibo/Pictures/Camera Roll/Combines/testing.mp4')
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
            fc = fc+1
            ret,frame = cap.read()
            image, results = mp_d(frame, holistic)
            draw_landmarks(image, results)        
            keypoints = extract_pts(results)
            print("appending->>>",fc)
            sequence.append(keypoints)
            sequence = sequence[-150:]
            print("SEQUENCE -->>> ",len(sequence))
            if len(sequence)%150==0:
                print("SEQUENCE IS FULL")
                if fc%150 == 0 :
                    
#                     print(len(sequence))
                    res = model3.predict(np.expand_dims(sequence, axis=0))[0]
                    print("res  ",res)
                    print("actions[np.argmax(res)] ---- ",actions[np.argmax(res)])
                    if res[np.argmax(res)] > threshold:
                        print("USER JUST DID {}, probability is {} ".format(actions[np.argmax(res)],res[np.argmax(res)]))
                        if actions[np.argmax(res)] == k:                            
                            print("USER JUST DID {}, we were looking for {}, hence increasing the counter ".format(actions[np.argmax(res)],k))
                            counter = counter+1
                            print("COUNTER -->>>>>",counter)
                else:
                    print("waiting for the window to slide",fc)
#             image = prob_viz(res, actions, image, colors)

            cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)                
            if counter >=1:       
                cv2.putText(image, str(counter), (3,30),cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA) 
            image = cv2.resize(image, dim)
            cv2.imshow('OpenCV Feed', image)
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
        cap.release()
        cv2.destroyAllWindows()  
else:
    print("RUN AGAIN AND ENTER { 0 }")
# Out:
# enter the 0 if you want to predict lunges0
# appending->>> 1
# SEQUENCE -->>>  1
# appending->>> 2
# SEQUENCE -->>>  2
# appending->>> 3
# SEQUENCE -->>>  3
# appending->>> 4
# SEQUENCE -->>>  4
# appending->>> 5
# SEQUENCE -->>>  5
# appending->>> 6
# SEQUENCE -->>>  6
# appending->>> 7
# SEQUENCE -->>>  7
# appending->>> 8
# SEQUENCE -->>>  8
# appending->>> 9
# SEQUENCE -->>>  9
# appending->>> 10
# SEQUENCE -->>>  10
# appending->>> 11
# SEQUENCE -->>>  11
# appending->>> 12
# SEQUENCE -->>>  12
# appending->>> 13
# SEQUENCE -->>>  13
# appending->>> 14
# SEQUENCE -->>>  14
# appending->>> 15
# SEQUENCE -->>>  15
# appending->>> 16
# SEQUENCE -->>>  16
# appending->>> 17
# SEQUENCE -->>>  17
# appending->>> 18
# SEQUENCE -->>>  18
# appending->>> 19
# SEQUENCE -->>>  19
# appending->>> 20
# SEQUENCE -->>>  20
# appending->>> 21
# SEQUENCE -->>>  21
# appending->>> 22
# SEQUENCE -->>>  22
# appending->>> 23
# SEQUENCE -->>>  23
# appending->>> 24
# SEQUENCE -->>>  24
# ...

# %%
label_map

# %%
cap.release()
cv2.destroyAllWindows()
